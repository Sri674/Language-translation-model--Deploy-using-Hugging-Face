# %%
# !pip install transformers sentencepiece

# %%
# !pip install sacremoses
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 897.5/897.5 kB 11.7 MB/s eta 0:00:00
# ...

# %%
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM

model_name = "Helsinki-NLP/opus-mt-en-dra"
tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForSeq2SeqLM.from_pretrained(model_name)

input_text = ">>tam<< Hello, how are you?"
inputs = tokenizer([input_text], return_tensors="pt", padding=True)

translated = model.generate(**inputs)
output = tokenizer.decode(translated[0], skip_special_tokens=True)

print("Translated to Tamil:", output)
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/44.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/1.40k [00:00<?, ?B/s]
# source.spm:   0%|          | 0.00/818k [00:00<?, ?B/s]
# target.spm:   0%|          | 0.00/1.17M [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/2.34M [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/308M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/293 [00:00<?, ?B/s]
# ...

# %%
# !pip install -U datasets fsspec huggingface_hub pyarrow
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 491.5/491.5 kB 15.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 193.6/193.6 kB 16.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 514.8/514.8 kB 32.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.3/42.3 MB 13.1 MB/s eta 0:00:00
# ...
#   Attempting uninstall: pyarrow
#     Found existing installation: pyarrow 18.1.0
#     Uninstalling pyarrow-18.1.0:
#       Successfully uninstalled pyarrow-18.1.0
#   Attempting uninstall: fsspec
#     Found existing installation: fsspec 2025.3.2
#     Uninstalling fsspec-2025.3.2:
#       Successfully uninstalled fsspec-2025.3.2
#   Attempting uninstall: huggingface_hub
#     Found existing installation: huggingface-hub 0.32.4
#     Uninstalling huggingface-hub-0.32.4:
#       Successfully uninstalled huggingface-hub-0.32.4
#   Attempting uninstall: datasets
#     Found existing installation: datasets 2.14.4
#     Uninstalling datasets-2.14.4:
# ...

# %%
from datasets import load_dataset
import pandas as pd

ds = load_dataset("ai4bharat/samanantar", "ta", split="train")

df = pd.DataFrame(ds)
df = df[['src', 'tgt']].rename(columns={'src': 'English', 'tgt': 'Tamil'})

df.head()
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# README.md:   0%|          | 0.00/11.4k [00:00<?, ?B/s]
# train-00000-of-00004.parquet:   0%|          | 0.00/189M [00:00<?, ?B/s]
# train-00001-of-00004.parquet:   0%|          | 0.00/189M [00:00<?, ?B/s]
# train-00002-of-00004.parquet:   0%|          | 0.00/188M [00:00<?, ?B/s]
# train-00003-of-00004.parquet:   0%|          | 0.00/188M [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/5264867 [00:00<?, ? examples/s]
# ...

# %%
import pandas as pd

df_trans = df.sample(n=100000, random_state=42)

# 2. Save to CSV file in Colab's temporary storage
df_trans.to_csv("english_tamil_sample_100k.csv", index=False)

# 3. Download the CSV to your local machine
from google.colab import files
files.download("english_tamil_sample_100k.csv")

# %%
import pandas as pd


dfT=pd.read_csv("/content/english_tamil_sample_100k.csv")
dfT
# Out:
#                                                  English  \
# 0      There are different theories concerning the me...
# 1      Fundamentals rights of citizens are being muzz...
# 2      Since 2006-2007, the procurement price of milk...
# 3                                           Rs 16 crore.
# 4      When you ran off precipitately and did not wai...
# ...                                                  ...
# 99995  "Commerce and Industry Minister Anand Sharma s...
# 99996                                     Electric buses
# 99997  Virat Kohli and Parthiv Patel will open the ba...
# 99998                                  At that time, Rs.
# 99999                    Police have arrested 3 persons.
#
#                                                    Tamil
# 0      பண்டாரம் என்ற வார்த்தையின் பொருளுக்கு வெவ்வேறு...
# 1      அடிப்படை சனநாயக உரிமைகள் இல்லாதொழிக்கப்பட்டு ...
# 2      இந்த அரசு பாலுக்கான கொள்முதல் விலையை பசும்பாலு...
# ...

# %%
dfT.shape
# Out:
# (100000, 2)

# %%
dfT.isnull().sum()
# Out:
# English    0
# Tamil      0
# dtype: int64

# %%
dfT.dtypes
# Out:
# English    object
# Tamil      object
# dtype: object

# %%
dfT["English"] = dfT["English"].str.strip()
dfT["Tamil"] = dfT["Tamil"].str.strip()

# %%
from sklearn.model_selection import train_test_split
from datasets import Dataset

train_df, test_df = train_test_split(dfT, test_size=0.2, random_state=42)


train_dataset = Dataset.from_pandas(train_df.reset_index(drop=True))
test_dataset = Dataset.from_pandas(test_df.reset_index(drop=True))

# %%
test_dataset
# Out:
# Dataset({
#     features: ['English', 'Tamil'],
#     num_rows: 20000
# })

# %%
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM

model_name = "Helsinki-NLP/opus-mt-en-dra"
tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForSeq2SeqLM.from_pretrained(model_name)
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/44.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/1.40k [00:00<?, ?B/s]
# source.spm:   0%|          | 0.00/818k [00:00<?, ?B/s]
# target.spm:   0%|          | 0.00/1.17M [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/2.34M [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/308M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/293 [00:00<?, ?B/s]

# %%
def preprocess_function(examples):
  return tokenizer(
        examples["English"],
        text_target=examples["Tamil"],
        padding="max_length",
        truncation=True,
        max_length=64
  )


train_dataset=train_dataset.map(preprocess_function,batched=True)
test_dataset=test_dataset.map(preprocess_function,batched=True)

train_dataset = train_dataset.select(range(2000))
test_dataset = test_dataset.select(range(500))
# Out:
# ...
# Map:   0%|          | 0/20000 [00:00<?, ? examples/s]

# %%
train_dataset
# Out:
# Dataset({
#     features: ['English', 'Tamil', 'input_ids', 'attention_mask', 'labels'],
#     num_rows: 2000
# })

# %%
test_dataset
# Out:
# Dataset({
#     features: ['English', 'Tamil', 'input_ids', 'attention_mask', 'labels'],
#     num_rows: 500
# })

# %%
train_dataset = train_dataset.remove_columns(["English", "Tamil"])
test_dataset = test_dataset.remove_columns(["English", "Tamil"])

# %%
train_dataset
# Out:
# Dataset({
#     features: ['input_ids', 'attention_mask', 'labels'],
#     num_rows: 2000
# })

# %%
test_dataset
# Out:
# Dataset({
#     features: ['input_ids', 'attention_mask', 'labels'],
#     num_rows: 500
# })

# %%
from transformers import AutoModelForSeq2SeqLM

model = AutoModelForSeq2SeqLM.from_pretrained("Helsinki-NLP/opus-mt-en-dra")

# %%
from transformers import DataCollatorForSeq2Seq

data_collator = DataCollatorForSeq2Seq(tokenizer=tokenizer, model=model)

# %%
from transformers import Seq2SeqTrainingArguments

training_args = Seq2SeqTrainingArguments(
    output_dir="./results",
    eval_strategy="epoch",
    learning_rate=3e-5,
    per_device_train_batch_size=8,
    per_device_eval_batch_size=8,
    weight_decay=0.01,
    save_total_limit=2,
    num_train_epochs=3,
    predict_with_generate=True,
    logging_dir="./logs",
    logging_steps=20,
    save_steps=500,
    generation_max_length=128,
    generation_num_beams=4
)

# %%
! pip install evaluate

# %%
import os
os.environ["WANDB_MODE"] = "disabled"

# %%
# !pip install sacrebleu

# %%
import evaluate
import numpy as np

# Load metric
metric = evaluate.load("sacrebleu")

# Fix tokenizer warnings
tokenizer.model_max_length = 128

# Step 1: Define postprocessing
def postprocess_text(preds, labels):
    preds = [pred.strip() for pred in preds]
    labels = [[label.strip()] for label in labels]
    return preds, labels

# Step 2: Compute BLEU properly
def compute_metrics(eval_preds):
    predictions, labels = eval_preds
    # Add beam search for better predictions
    decoded_preds = tokenizer.batch_decode(predictions, skip_special_tokens=True)

    # Replace -100 in labels
    labels = np.where(labels != -100, labels, tokenizer.pad_token_id)
    decoded_labels = tokenizer.batch_decode(labels, skip_special_tokens=True)

    decoded_preds, decoded_labels = postprocess_text(decoded_preds, decoded_labels)
    result = metric.compute(predictions=decoded_preds, references=decoded_labels)
    return {"bleu": result["score"]}

# %%
from transformers import Seq2SeqTrainer

trainer = Seq2SeqTrainer(
    model=model,
    args=training_args,
    train_dataset=train_dataset,
    eval_dataset=test_dataset,
    tokenizer=tokenizer,
    data_collator=data_collator,
    compute_metrics=compute_metrics
)

# Train
trainer.train()
# Out:
# <ipython-input-35-2029215977>:3: FutureWarning: `tokenizer` is deprecated and will be removed in version 5.0.0 for `Seq2SeqTrainer.__init__`. Use `processing_class` instead.
#   trainer = Seq2SeqTrainer(
#     <div>
#
#       <progress value='750' max='750' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [750/750 04:06, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Bleu</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.518400</td>
#       <td>1.103698</td>
#       <td>6.187735</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.439500</td>
#       <td>1.123935</td>
#       <td>5.412818</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.354900</td>
#       <td>1.132046</td>
#       <td>5.887252</td>
#     </tr>
#   </tbody>
# </table><p>
# ...

# %%
print(model)
# Out:
# MarianMTModel(
#   (model): MarianModel(
#     (shared): Embedding(62952, 512, padding_idx=62951)
#     (encoder): MarianEncoder(
#       (embed_tokens): Embedding(62952, 512, padding_idx=62951)
#       (embed_positions): MarianSinusoidalPositionalEmbedding(512, 512)
#       (layers): ModuleList(
#         (0-5): 6 x MarianEncoderLayer(
#           (self_attn): MarianAttention(
#             (k_proj): Linear(in_features=512, out_features=512, bias=True)
#             (v_proj): Linear(in_features=512, out_features=512, bias=True)
#             (q_proj): Linear(in_features=512, out_features=512, bias=True)
#             (out_proj): Linear(in_features=512, out_features=512, bias=True)
#           )
#           (self_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#           (activation_fn): SiLU()
#           (fc1): Linear(in_features=512, out_features=2048, bias=True)
#           (fc2): Linear(in_features=2048, out_features=512, bias=True)
# ...

# %%
print(trainer)

# %%
import shutil
import os



# Define a local directory to save the model on your H: drive
model_save_path = r"H:\saved_model"  # Using raw string (r"") to avoid issues with backslashes

# Save the trained model and tokenizer to the specified directory
trainer.save_model(model_save_path)
tokenizer.save_pretrained(model_save_path)

# Define the path for the .zip file on your H: drive
zip_file_path = r'H:\trained_model.zip'

# Compress the directory into a .zip file
shutil.make_archive(zip_file_path.replace('.zip', ''), 'zip', model_save_path)

print(f"Model saved and compressed as {zip_file_path}")
# Out:
# Model saved and compressed as H:\trained_model.zip
